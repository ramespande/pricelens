# %% [markdown]
# # CPU baselines
# Run `python scripts/run_baselines.py --data-root $DATA_ROOT` first; inspect `experiments/results/baselines.csv` here.

# %%
import pandas as pd
pd.read_csv('experiments/results/baselines.csv')
